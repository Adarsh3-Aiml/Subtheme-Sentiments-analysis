# %% [markdown]
# # Model Analysis  BERT-BASE-UNCASED

# %%
# jupyter nbconvert yourNotebook.ipynb --no-input --no-prompt
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
metric = open('output/bert_base_metrics.pkl', 'rb')      
k = pickle.load(metric) 
metric.close()

# %% [markdown]
# ## Training and Validation BCE-Loss Plot

# %%
plt.plot(met['epochs'],met['train_loss'],c='red', label = 'training')
plt.plot(met['epochs'],met['val_loss'],c='blue', label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### As we can se at epoch 5 train and validation are low and after that validaton loss is greater as compared to training, So there is overfitting after 5th Epoch

# %% [markdown]
# ## Training and Validation F1-Micro-Score Plot

# %%
plt.plot(met['epochs'],met['training_f1_micro'],c='red', label = 'training')
plt.plot(met['epochs'],met['val_f1_micro'],c='blue',label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('F1-Micro-Score')
plt.title('Training and Validation F1-Micro-Score')
plt.legend()
plt.show()

# %% [markdown]
# #### Here also we can see that after 5th epoch validation F1-Micro-Score is not increasing while training F1-Micro-Score is increasing which shows overfitting after 5th Epoch, Training F1-Micro-Score reached to .90 at 10th Epoch

# %% [markdown]
# ## Training and Validation F1-Macro-Score Plot

# %%
plt.plot(met['epochs'],met['training_f1_macro'],c='red', label = 'training')
plt.plot(met['epochs'],met['val_f1_macro'],c='blue',label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('F1-Macro-Score')
plt.title('Training and Validation F1-Marco-Score')
plt.legend()
plt.show()

# %% [markdown]
# #### Here also we can see that after 5th epoch validation F1-Macro-Score is not increasing while training F1-Macro-Score is increasing which shows overfitting after 5th Epoch, Training F1-Macro-Score reached to .85 at 10th Epoch

# %% [markdown]
# ## Training and Validation Hamming Loss Plot

# %%
plt.plot(met['epochs'],met['training_hamming_loss'],c='red', label = 'training')
plt.plot(met['epochs'],met['val_hamming_loss'],c='blue',label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('Hamming-Loss')
plt.title('Training and Validation Hamming-Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### As we can se at epoch 5 train and validation are low and after that validaton loss is greater as compared to training, So there is overfitting after 5th Epoch

# %% [markdown]
# # Model Analysis  BERT-LARGE-UNCASED

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
metric = open('output/bert_large_metrics.pkl', 'rb')      
met = pickle.load(metric) 
metric.close()

# %% [markdown]
# ## Training and Validation BCE-Loss Plot

# %%
sns.set(rc={'figure.figsize':(11.4,6.00)})
plt.plot(met['epochs'],met['train_loss'],c='red', label = 'training')
plt.plot(met['epochs'],met['val_loss'],c='blue', label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### As we can se at epoch 5 train and validation are low and close to each other and after that validaton loss is very low at 8th epoch but training loss is greater so at 5th epoch our model is performing best

# %% [markdown]
# ## Training and Validation F1-Micro-Score Plot

# %%
plt.plot(met['epochs'],met['training_f1_micro'],c='red', label = 'training')
plt.plot(met['epochs'],met['val_f1_micro'],c='blue',label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('F1-Micro-Score')
plt.title('Training and Validation F1-Micro-Score')
plt.legend()
plt.show()

# %% [markdown]
# #### we can see that at 10th epoch there is a big difference in train and validation f1-micro-score and after 5th epoch training f1-micro is increasing faster as compared to validation f1-micro-score

# %% [markdown]
# ## Training and Validation F1-Macro-Score Plot

# %%
plt.plot(met['epochs'],met['training_f1_macro'],c='red', label = 'training')
plt.plot(met['epochs'],met['val_f1_macro'],c='blue',label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('F1-Macro-Score')
plt.title('Training and Validation F1-Marco-Score')
plt.legend()
plt.show()

# %% [markdown]
# #### As we can see that after 6th epoch validation f1-macro-score is not increasing as much with respect to training  f1-macro-score

# %% [markdown]
# ## Training and Validation Hamming Loss Plot

# %%
plt.plot(met['epochs'],met['training_hamming_loss'],c='red', label = 'training')
plt.plot(met['epochs'],met['val_hamming_loss'],c='blue',label = 'validation')
plt.xlabel('Epochs')
plt.ylabel('Hamming-Loss')
plt.title('Training and Validation Hamming-Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### As we can se at epoch 5 train and validation are low and after that validaton loss is greater as compared to training

# %% [markdown]
# ## Conclustion

# %% [markdown]
# * Bert Large Uncased Model is performing slightly better as compared to Bert Base Uncased and also there is less overfitting till 10th epoch in Large model as compared to Base model
